# %%
# Import Dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# data files
df_file_to_load = "Crash_Data.csv"
df_Crash_data = pd.read_csv(file_to_load)
df_Crash_data.head()
# Out:
# C:\Users\saleh\anaconda2\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (10,14,15,16,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Crash ID State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# 0  20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 1  20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 2  20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 3  20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 4  20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ... Age  \
# 0                           NaN                           NaN  ...  38
# 1                            No                            No  ...  28
# ...

# %%
# Import the source data and merge.
#df_crashes = pd.read_csv('crashes.csv', low_memory=False)
#df_crashes = pd.read_csv('Crash_Data.csv', low_memory=False).drop('CRASH_DATE', axis=1)


# Display the total number of crashes.
print('Total Number of Reported Crashes:', df['CRASH_ID'].nunique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-995866b6bec2> in <module>
#       5
#       6 # Display the total number of crashes.
# ----> 7 print('Total Number of Reported Crashes:', df['CRASH_ID'].nunique())
#
# NameError: name 'df' is not defined
