# %%
# Declare dependencies
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns
import os as os

#Display data summary
crash_data = os.path.join("resources/Crash_Data.csv")
crash_data = pd.read_csv(crash_data, low_memory=False)
crash_data.head()
# Out:
#    Crash ID State  Month  Year   Dayweek   Time Crash Type Bus Involvement  \
# 0  20212133   Vic      9  2021    Sunday   0:30     Single             NaN
# 1  20214022    SA      9  2021  Saturday  23:31   Multiple              No
# 2  20212096   Vic      9  2021  Saturday  23:00     Single             NaN
# 3  20212145   Vic      9  2021  Saturday  22:25     Single             NaN
# 4  20212075   Vic      9  2021  Saturday   5:15     Single             NaN
#
#   Heavy Rigid Truck Involvement Articulated Truck Involvement  ... Age  \
# 0                           NaN                           NaN  ...  38
# 1                            No                            No  ...  28
# 2                           NaN                           NaN  ...  19
# 3                           NaN                           NaN  ...  23
# 4                           NaN                           NaN  ...  46
#
#    National Remoteness Areas           SA4 Name 2016  National LGA Name 2017  \
# ...

# %%
# Create bar chart displaying types of road users involved in fatal accidents

#my_xticks = ['Motorcycle Rider', 'Pedestrian', 'Car Passenger', 'Car Driver', 'Other', 'Cyclist', 'Motorcycle passenger']

plt.bar(crash_data['Road User'].unique(),
        crash_data['Road User'].value_counts(), 
        color='crimson')
plt.rcParams["figure.figsize"] = (28, 10)
plt.xlabel('Types of Road Users', fontdict = {'fontsize' : 20})
plt.ylabel('Total Fatal Accidents (1989-2011)', fontdict = {'fontsize' : 20})
plt.title('Road Users Involved in Fatal Accidents', fontdict = {'fontsize' : 50})
#ax.set_xticklabels = 'Motorcycle Rider', 'Pedestrian', 'Car Passenger', 'Car Driver', 'Other', 'Cyclist', 'Motorcycle passenger'

#plt.xticks(x, my_xticks)
#plt.show()
plt.savefig('Road Users Bar Chart.png')

# %%
# Create pie chart displaying types of road users involved in fatal accidents

#labels = 'Motorcycle Rider', 'Pedestrian', 'Passenger', 'Driver', 'Other', 'Cyclist', 'Motorcycle pillion passenger'
#sizes = [15, 30, 45, 10, 10, 10, 10]
#explode = (0.1, 0, 0, 0, 0, 0, 0)  # only "explode" the 1st slice

#fig1, ax1 = plt.subplots()
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
      #  shadow=True, startangle=90)
#ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

#plt.show()

#fig.savefig('Road Users Bar Chart.jpg')

# %%
#df = pd.read_csv ('chart_work.csv')

#sums = df.groupby(crash_data["Product Name;"])["Number Of Bugs"].sum()
#axis('equal');
#pie(sums, labels=sums.index);
#show()

# %%
crash_pie = crash_data['Road User'].value_counts()
my_labels = 'Motorcycle Rider', 'Pedestrian', 'Car Passenger', 'Car Driver', 'Other', 'Cyclist', 'Motorcycle passenger'
myexplode = [0.1, 0, 0, 0, 0, 0, 0]
plt.pie(crash_pie, 
        labels=my_labels, 
        startangle=0, 
        #autopct='%1.1f%%', 
        explode = myexplode,
        shadow=True,
        textprops={'fontsize': 10})
plt.title('Road Users Involved in Fatal Accidents', fontdict = {'fontsize' : 30})
plt.axis('equal')
#plt.show()
#plt.savefig('Road Users Pie Chart.png')
# Out:
# (-1.1294683943887383,
#  1.1175661313545826,
#  -1.1154871266977422,
#  1.2302369427790714)

# %%
crash_data = pd.DataFrame({'Q10_Ans':['Boomer','Gen X','Gen Y','Gen Z'],'Q4_Agree':[2,3,4,5]})

fig, ax = plt.subplots(figsize=[10,6])
labels = crash_data['Q10_Ans']
ax.pie(x=data['Q4_Agree'], autopct="%.1f%%", explode=[0.05]*4, labels=labels, pctdistance=0.5)
ax.set_title("Generations that agree data visualization will help with job prospects", fontsize=14);
#plt.savefig("DeliveryPieChart.png")
